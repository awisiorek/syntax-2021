# %% [markdown]
# ***Vorlesung 'Syntax natürlicher Sprachen', WS 2020/21***
#
# ---
# # Übung 6 (Lösung)

# %%
from exercises_6 import *
from questions import aufgabe
from nltk.tree import Tree
from nltk import FeatStruct
from sklearn.metrics import accuracy_score

# %% [markdown]
# ---
# ## Aufgabe 1: Kongruenz 1.0
# #### Betrachten Sie die folgenden Sätze. Offensichtlich besteht zwischen Artikel und Nomen einer Nominalphrase Kongruenz im Genus.
# ####  Nutzen Sie Merkmalstrukturen in einem Python-Skript zur Überprüfung dieser Kongruenz. Ihr Skript sollte alle untenstehenden Beispiele korrekt als grammatisch/ungrammatisch klassifizieren können.
#
# *Informieren Sie sich auf http://www.nltk.org/howto/featstruct.html bzgl. der NLTK-`unify`-Methode.*

# %% [markdown]
#
# 1. - *Der Löffel ist aus Silber.*
#    - *&ast; Der Gabel ist aus Silber.*
#    - *&ast; Der Messer ist aus Silber.* <p>
#
# 2. - *&ast; Die Löffel ist aus Silber.*
#    - *Die Gabel ist aus Silber.*
#    - *&ast; Die Messer ist aus Silber.* <p>
#
# 3. - *&ast; Das Löffel ist aus Silber.*
#    - *&ast; Das Gabel ist aus Silber.*
#    - *Das Messer ist aus Silber.*

# %%
test_cases = [
    (det, noun)
    for det in ["der", "die", "das"]
    for noun in ["Löffel", "Gabel", "Messer"]
]
truth = [
    True, False, False,
    False, True, False,
    False, False, True
]

# %%
test_cases
# Out:
# [('der', 'Löffel'),
#  ('der', 'Gabel'),
#  ('der', 'Messer'),
#  ('die', 'Löffel'),
#  ('die', 'Gabel'),
#  ('die', 'Messer'),
#  ('das', 'Löffel'),
#  ('das', 'Gabel'),
#  ('das', 'Messer')]

# %%
lexicon = {
    "der": FeatStruct(GEN="mask"),
    "die": FeatStruct(GEN="fem"),
    "das": FeatStruct(GEN="neutr"),
    "Messer": FeatStruct(CAT="N", GEN="neutr"),
    "Gabel": FeatStruct(CAT="N", GEN="fem"),
    "Löffel": FeatStruct(CAT="N", GEN="mask")
}

def is_correct(det, noun):
    # return lexicon[det] == lexicon[noun]
    return lexicon[det].unify(lexicon[noun]) is not None

# %%
lexicon["der"].unify(lexicon["Löffel"])
# Out:
# [CAT='N', GEN='mask']

# %%
# Evaluation
pred = []
for nomPhr in test_cases:
    pred.append(is_correct(*nomPhr))

print("Accuracy: {:.2f} %".format(accuracy_score(truth, pred)*100))
# Out:
# Accuracy: 100.00 %

# %% [markdown]
# ---
# ## Aufgabe 2: Semantische Merkmalstrukturen
# #### Implementieren Sie die folgenden Merkmalstrukturen als `nltk.FeatStruct` und schreiben Sie ein Programm, das für einen gegebenen Satz die richtige Merkmalstruktur aus dem Lexikon auswählt und die Lücken für Subjekt und Objekt des Satzes füllt. Geben Sie anschließend die vollständige Merkmalstruktur auf der Standardausgabe aus.

# %% [markdown]
# $$
# \left [ % draw the opening left bracket
# \begin{array}{ll}   % begin a two column array
#    CAT & V \\
#    LEMMA & \text{folgen} \\
#    SYN &  \left  [ \begin{array}{ll}
#                         SBJ & \boxed{1}\\
#                         OBJ & \boxed{2} \\
#                     \end{array}
#            \right  ]  \\
#    SEM   & \left [ \begin{array}{ll}
#                           AGT & \boxed{1} \\
#                           PAT & \boxed{2} \\
#                    \end{array}
#            \right ]
# \end{array} % end the outer array
# \right ]    % closing right bracket
# ~~~~~~~~~~
# \left [ % draw the opening left bracket
# \begin{array}{ll}   % begin a two column array
#    CAT & V \\
#    LEMMA & \text{überraschen} \\
#    SYN &  \left  [ \begin{array}{ll}
#                         SBJ & \boxed{1}\\
#                         OBJ & \boxed{2} \\
#                     \end{array}
#            \right  ]  \\
#    SEM   & \left [ \begin{array}{ll}
#                           SRC & \boxed{1} \\
#                           EXP & \boxed{2} \\
#                    \end{array}
#            \right ]
# \end{array} % end the outer array
# \right ]    % closing right bracket
# $$

# %% [markdown]
# #### _Anmerkung_: Sie dürfen annehmen, dass  wir es nur mit sehr einfachen Sätzen zu tun haben, in denen das Token direkt vor dem Verb dem Subjekt und das Token direkt danach dem Objekt entspricht.  *Alternativ können Sie auch einen Parser wie spaCy verwenden.*
#
# #### Testen Sie Ihr Programm mit den folgenden Sätzen:

# %%
sentences = [
   "Das überrascht mich doch sehr!",
   "Wer folgt wem auf Twitter?",
   "John überrascht Jane mit einer richtigen Antwort.",
   "Der Hund ist mir bis nach Hause gefolgt!"    
]

# %%
lexicon = {
    "folgen": FeatStruct("[CAT=V, LEMMA=folgen,"+
                        "SYN=[SBJ=?x, OBJ=?y],"+
                        "SEM=[AGT=?x, PAT=?y]]"
                       ),
    "überraschen": FeatStruct("[CAT=V, LEMMA=ueberraschen,"+
                        "SYN=[SBJ=?x, OBJ=?y],"+
                        "SEM=[SRC=?x, EXP=?y]]"
                             )
}

# %%
import spacy
nlp = spacy.load('de_core_news_sm')

# %%
#  In: sentence as a string
# Out: semantic feature structure
def semantic_parse(sentence):
    analyzed = nlp(sentence)
    sbj, obj, verb = None, None, None
    for token in analyzed:
        if token.dep_ == 'sb':
            sbj = token.text
        elif token.dep_ == 'oa' or token.dep_ == 'da':
            obj = token.text
        elif token.pos_ == 'VERB':
            verb = token.lemma_
    if sbj is None or obj is None or verb is None:
        raise RuntimeError('I could not identify all relevant parts: {} - {} - {}'.format(sbj, verb, obj))
    return lexicon[verb].unify(
        FeatStruct(SYN=FeatStruct(SBJ=sbj, OBJ=obj))
    )

# %%
for sent in sentences:
    fs = semantic_parse(sent)
    print()
    print(sent)
    print(fs)
# Out:
# Das überrascht mich doch sehr!
# [ CAT   = 'V'              ]
# [ LEMMA = 'ueberraschen'   ]
# [                          ]
# [ SEM   = [ EXP = 'mich' ] ]
# [         [ SRC = 'Das'  ] ]
# [                          ]
# [ SYN   = [ OBJ = 'mich' ] ]
# [         [ SBJ = 'Das'  ] ]
#
# Wer folgt wem auf Twitter?
# [ CAT   = 'V'             ]
# [ LEMMA = 'folgen'        ]
# [                         ]
# [ SEM   = [ AGT = 'Wer' ] ]
# [         [ PAT = 'wem' ] ]
# [                         ]
# [ SYN   = [ OBJ = 'wem' ] ]
# [         [ SBJ = 'Wer' ] ]
#
# John überrascht Jane mit einer richtigen Antwort.
# [ CAT   = 'V'              ]
# [ LEMMA = 'ueberraschen'   ]
# [                          ]
# [ SEM   = [ EXP = 'Jane' ] ]
# [         [ SRC = 'John' ] ]
# [                          ]
# [ SYN   = [ OBJ = 'Jane' ] ]
# [         [ SBJ = 'John' ] ]
#
# Der Hund ist mir bis nach Hause gefolgt!
# [ CAT   = 'V'              ]
# [ LEMMA = 'folgen'         ]
# [                          ]
# [ SEM   = [ AGT = 'Hund' ] ]
# [         [ PAT = 'mir'  ] ]
# [                          ]
# [ SYN   = [ OBJ = 'mir'  ] ]
# [         [ SBJ = 'Hund' ] ]

# %%
from spacy import displacy

for sentence in sentences:
    sent = nlp(sentence)
    for token in sent:
        print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop, sep='\t')
    displacy.render(sent, style='dep', options={'distance':100})
# Out:
# Das	der	PRON	PDS	sb	Xxx	True	True
# überrascht	überraschen	VERB	VVFIN	ROOT	xxxx	True	False
# mich	sich	PRON	PPER	oa	xxxx	True	True
# doch	doch	ADV	ADV	mo	xxxx	True	True
# sehr	sehr	ADV	ADV	mo	xxxx	True	True
# !	!	PUNCT	$.	punct	!	False	False
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="de" id="bd04258422ea4d4a885cd7fdf3d91455-0" class="displacy" width="550" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Das</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">überrascht</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">mich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">doch</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">sehr!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bd04258422ea4d4a885cd7fdf3d91455-0-0" stroke-width="2px" d="M70,152.0 C70,102.0 140.0,102.0 140.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bd04258422ea4d4a885cd7fdf3d91455-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">sb</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bd04258422ea4d4a885cd7fdf3d91455-0-1" stroke-width="2px" d="M170,152.0 C170,102.0 240.0,102.0 240.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bd04258422ea4d4a885cd7fdf3d91455-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">oa</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M240.0,154.0 L248.0,142.0 232.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bd04258422ea4d4a885cd7fdf3d91455-0-2" stroke-width="2px" d="M170,152.0 C170,52.0 345.0,52.0 345.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bd04258422ea4d4a885cd7fdf3d91455-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mo</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M345.0,154.0 L353.0,142.0 337.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bd04258422ea4d4a885cd7fdf3d91455-0-3" stroke-width="2px" d="M170,152.0 C170,2.0 450.0,2.0 450.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bd04258422ea4d4a885cd7fdf3d91455-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mo</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,154.0 L458.0,142.0 442.0,142.0" fill="currentColor"/>
# </g>
# </svg>
# Wer	Wer	PRON	PWS	sb	Xxx	True	True
# folgt	folgen	VERB	VVFIN	ROOT	xxxx	True	False
# wem	wer	PRON	PWS	da	xxx	True	True
# auf	auf	ADP	APPR	mo	xxx	True	True
# Twitter	Twitter	NOUN	NN	nk	Xxxxx	True	False
# ?	?	PUNCT	$.	punct	?	False	False
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="de" id="c3520c3917024066bf24c1b6de5b9e4f-0" class="displacy" width="550" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Wer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">folgt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">wem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">auf</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">Twitter?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c3520c3917024066bf24c1b6de5b9e4f-0-0" stroke-width="2px" d="M70,102.0 C70,52.0 145.0,52.0 145.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c3520c3917024066bf24c1b6de5b9e4f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">sb</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,104.0 L62,92.0 78,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c3520c3917024066bf24c1b6de5b9e4f-0-1" stroke-width="2px" d="M170,102.0 C170,52.0 245.0,52.0 245.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c3520c3917024066bf24c1b6de5b9e4f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">da</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245.0,104.0 L253.0,92.0 237.0,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c3520c3917024066bf24c1b6de5b9e4f-0-2" stroke-width="2px" d="M170,102.0 C170,2.0 350.0,2.0 350.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c3520c3917024066bf24c1b6de5b9e4f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mo</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M350.0,104.0 L358.0,92.0 342.0,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c3520c3917024066bf24c1b6de5b9e4f-0-3" stroke-width="2px" d="M370,102.0 C370,52.0 445.0,52.0 445.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c3520c3917024066bf24c1b6de5b9e4f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445.0,104.0 L453.0,92.0 437.0,92.0" fill="currentColor"/>
# </g>
# </svg>
# John	John	PROPN	NE	sb	Xxxx	True	False
# überrascht	überraschen	VERB	VVFIN	ROOT	xxxx	True	False
# Jane	Jane	PROPN	NE	oa	Xxxx	True	False
# mit	mit	ADP	APPR	mo	xxx	True	True
# einer	einer	DET	ART	nk	xxxx	True	True
# richtigen	richtig	ADJ	ADJA	nk	xxxx	True	False
# Antwort	Antwort	NOUN	NN	nk	Xxxxx	True	False
# .	.	PUNCT	$.	punct	.	False	False
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="de" id="56859652a8b14725978471e92ebef12c-0" class="displacy" width="750" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">John</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">überrascht</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">Jane</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">mit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">einer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">richtigen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Antwort.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-56859652a8b14725978471e92ebef12c-0-0" stroke-width="2px" d="M70,152.0 C70,102.0 140.0,102.0 140.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-56859652a8b14725978471e92ebef12c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">sb</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-56859652a8b14725978471e92ebef12c-0-1" stroke-width="2px" d="M170,152.0 C170,102.0 240.0,102.0 240.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-56859652a8b14725978471e92ebef12c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">oa</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M240.0,154.0 L248.0,142.0 232.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-56859652a8b14725978471e92ebef12c-0-2" stroke-width="2px" d="M170,152.0 C170,52.0 345.0,52.0 345.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-56859652a8b14725978471e92ebef12c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mo</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M345.0,154.0 L353.0,142.0 337.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-56859652a8b14725978471e92ebef12c-0-3" stroke-width="2px" d="M470,152.0 C470,52.0 645.0,52.0 645.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-56859652a8b14725978471e92ebef12c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,154.0 L462,142.0 478,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-56859652a8b14725978471e92ebef12c-0-4" stroke-width="2px" d="M570,152.0 C570,102.0 640.0,102.0 640.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-56859652a8b14725978471e92ebef12c-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,154.0 L562,142.0 578,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-56859652a8b14725978471e92ebef12c-0-5" stroke-width="2px" d="M370,152.0 C370,2.0 650.0,2.0 650.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-56859652a8b14725978471e92ebef12c-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,154.0 L658.0,142.0 642.0,142.0" fill="currentColor"/>
# </g>
# </svg>
# Der	der	DET	ART	nk	Xxx	True	True
# Hund	Hund	NOUN	NN	sb	Xxxx	True	False
# ist	sein	AUX	VAFIN	ROOT	xxx	True	True
# mir	sich	PRON	PPER	da	xxx	True	True
# bis	bis	ADP	APPR	ac	xxx	True	True
# nach	nach	ADP	APPR	mo	xxxx	True	True
# Hause	hausen	NOUN	NN	nk	Xxxxx	True	False
# gefolgt	folgen	VERB	VVPP	oc	xxxx	True	False
# !	!	PUNCT	$.	punct	!	False	False
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="de" id="e0a053ed890342a9b580c75d70c7dd41-0" class="displacy" width="850" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Der</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">Hund</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">ist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">mir</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">bis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">nach</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Hause</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">gefolgt!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e0a053ed890342a9b580c75d70c7dd41-0-0" stroke-width="2px" d="M70,202.0 C70,152.0 135.0,152.0 135.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e0a053ed890342a9b580c75d70c7dd41-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e0a053ed890342a9b580c75d70c7dd41-0-1" stroke-width="2px" d="M170,202.0 C170,152.0 235.0,152.0 235.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e0a053ed890342a9b580c75d70c7dd41-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">sb</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,204.0 L162,192.0 178,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e0a053ed890342a9b580c75d70c7dd41-0-2" stroke-width="2px" d="M370,202.0 C370,52.0 745.0,52.0 745.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e0a053ed890342a9b580c75d70c7dd41-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">da</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,204.0 L362,192.0 378,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e0a053ed890342a9b580c75d70c7dd41-0-3" stroke-width="2px" d="M470,202.0 C470,152.0 535.0,152.0 535.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e0a053ed890342a9b580c75d70c7dd41-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ac</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,204.0 L462,192.0 478,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e0a053ed890342a9b580c75d70c7dd41-0-4" stroke-width="2px" d="M570,202.0 C570,102.0 740.0,102.0 740.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e0a053ed890342a9b580c75d70c7dd41-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mo</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,204.0 L562,192.0 578,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e0a053ed890342a9b580c75d70c7dd41-0-5" stroke-width="2px" d="M570,202.0 C570,152.0 635.0,152.0 635.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e0a053ed890342a9b580c75d70c7dd41-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M635.0,204.0 L643.0,192.0 627.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e0a053ed890342a9b580c75d70c7dd41-0-6" stroke-width="2px" d="M270,202.0 C270,2.0 750.0,2.0 750.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e0a053ed890342a9b580c75d70c7dd41-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">oc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,204.0 L758.0,192.0 742.0,192.0" fill="currentColor"/>
# </g>
# </svg>

# %% [markdown]
# ---
# ## Aufgabe 3: Adjektivdeklination
#
# #### Die Adjektivdeklination im Deutschen bereitet vielen Deutschlernern Schwierigkeiten. Stellen Sie sich vor, Sie wollten einem Deutschlerner plausibel machen, dass die Adjektivdeklination keine reine Willkür ist.
#
# #### Wählen Sie zur Illustration *das alte Bier* und *altes Bier*, und deklinieren Sie diese Nominalphrasen in allen vier Kasus.
#
# #### Auf welche Gesetzmäßigkeiten würden Sie hinweisen?
#
# #### Beantworten Sie auch die folgenden Fragen!

# %% [markdown]
# | Nominativ | altes Bier | das alte Bier
# | ---------- | ----------------- | ----------------- |
# | Genitiv | alten Biers | des alten Biers |
# | Dativ | altem Bier | dem alten Bier |
# | Akkusativ | altes Bier | das alte Bier |

# %%
aufgabe(blatt6_3)
# Out:
# SingleChoice(children=(HTML(value='<h4 style="font-size:14px;">Wie wird die Deklination der Nominalphrase <i>a…
# SingleChoice(children=(HTML(value='<h4 style="font-size:14px;">Wie wird die Deklination der Nominalphrase <i>d…
# SingleChoice(children=(HTML(value='<h4 style="font-size:14px;">Für die Deklination ist hier relevant, ob das A…
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Welche Aussagen über Adjektive stimmen?</h4>'…
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Welche Aussagen gelten für Nominalphrasen mit…
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Welche Aussagen gelten für den Fall, dass das…

# %% [markdown]
# ---
# ## Aufgabe 4: Diathesen
#
# #### Erläutern Sie, welche syntaktischen und welche kommunikativ-funktionalen Unterschiede zwischen den folgenden beiden Sätzen bestehen.
#
# - *Hausmeister Meier ruft die Feuerwehr an.*
# - *Die Feuerwehr wird von Hausmeister Meier angerufen.*
#
# #### Beantworten Sie auch die folgenden Fragen.

# %%
aufgabe(blatt6_4)
# Out:
# SingleChoice(children=(HTML(value='<h4 style="font-size:14px;">Schildern beide Sätze denselben Sachverhalt?</h…
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Welche syntaktischen Unterschiede bestehen?</…
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Welche kommunikativ-funktionalen Unterschiede…

# %% [markdown]
# ---
# ## Aufgabe 5: Semantische Hierarchie
#
# #### Vergleichen Sie die folgenden beiden Sätze:
# - *Peter zerreißt Paul die Hose*
# - *Die Hose zerreißt*
#
# #### Wie kann im Rahmen einer funktionalen Syntaxtheorie (vgl. die semantische Hierarchie <code> Ag > Pat > Rec > Ben > Instr > Loc > Time </code>) erklärt werden, dass hier im Subjekt jeweils eine andere semantische Funktion/Rolle steht?
#
# #### Beantworten Sie die folgenden Fragen.

# %%
aufgabe(blatt6_5)
# Out:
# SingleChoice(children=(HTML(value='<h4 style="font-size:14px;">Was ist der bevorzugte Kandidat zur Realisierun…
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Was passiert nach semantischer Hierarchie, we…
# SingleChoice(children=(HTML(value='<h4 style="font-size:14px;">Was ist im zweiten Satz das Subjekt?</h4>', lay…

# %% [markdown]
# ---
# ## Aufgabe 6: Topik-Fokus
#
# #### Konstruieren Sie einen Satz, in dem die fokussierte Information am Satzanfang steht. Stellen Sie diesen Satz in einen Minimalkontext, um nachzuweisen, dass das satzeinleitende Glied in der Tat im Fokus steht.
#
# #### Ihr Satz könnte die Wörter *Affe* und *Tisch* beinhalten.

# %% [markdown]
# Wer sitzt auf dem Tisch?
# Der Affe sitzt auf dem Tisch.

# %% [markdown]
# ---
# # Hausaufgaben

# %% [markdown]
# ---
# ## Aufgabe 7: Kongruenz 2.0
#
# #### Wie wir in Aufgabe 1 gesehen haben, besteht zwischen Artikel und Nomen einer Nominalphrase Kongruenz. Durch den Satzkontext haben wir erzwungen, dass Numerus und Kasus der Beispiele immer konstant waren (Singular, Nominativ). Lassen wir diese Einschränkung weg, ergeben sich noch weitere grammatische Kombinationsmöglichkeiten.
#
# | - | Messer | Gabel | Löffel
# | --- | ----------------- | ----------------- | ----------------- |
# | der | Pl. Gen. | Sg. Gen./Dat. | Sg. Nom./Pl. Gen. |
# | des | * | * | * |
# | dem | Sg. Dat. | * | Sg. Dat. |
# | den | * | * | Sg. Akk. |
# | die | Pl. Nom./Akk. | Sg. Nom./Akk. | Pl. Nom./Akk. |
# | das | Sg. Nom./Akk. | * | * |

# %% [markdown]
# #### Betrachten Sie das folgende mit Merkmalstrukturen implementierte Vollformlexikon. Schreiben Sie darauf aufbauend ein Programm, dass alle 18 Kombinationen aus obenstehender Tabelle als grammatisch oder ungrammatisch klassifiziert und im ersten Fall die unifizierte(n) Merkmalstruktur(en) ausgibt.

# %%
lexicon = {
    "Messer": [
        FeatStruct(GEN="neu", NUM="sg", KAS="nom"),
        FeatStruct(GEN="neu", NUM="sg", KAS="akk"),
        FeatStruct(GEN="neu", NUM="sg", KAS="dat"),
        FeatStruct(GEN="neu", NUM="pl", KAS="nom"),
        FeatStruct(GEN="neu", NUM="pl", KAS="akk"),
        FeatStruct(GEN="neu", NUM="pl", KAS="gen")
    ],
    "Gabel": [FeatStruct(NUM="sg", GEN="fem")],
    "Löffel": [
        FeatStruct(GEN="mas", NUM="sg", KAS="nom"),
        FeatStruct(GEN="mas", NUM="sg", KAS="akk"),
        FeatStruct(GEN="mas", NUM="sg", KAS="dat"),
        FeatStruct(GEN="mas", NUM="pl", KAS="nom"),
        FeatStruct(GEN="mas", NUM="pl", KAS="akk"),
        FeatStruct(GEN="mas", NUM="pl", KAS="gen"),
    ],

    "der": [
        FeatStruct(NUM="sg", GEN="mas", KAS="nom"),
        FeatStruct(NUM="sg", GEN="fem", KAS="dat"),
        FeatStruct(NUM="sg", GEN="fem", KAS="gen"),
        FeatStruct(NUM="pl", KAS="gen")
    ],
    "des": [
        FeatStruct(NUM="sg", GEN="mas", KAS="gen"),
        FeatStruct(NUM="sg", GEN="neu", KAS="gen")
    ],
    "dem": [
        FeatStruct(NUM="sg", GEN="mas", KAS="dat"),
        FeatStruct(NUM="sg", GEN="neu", KAS="dat"),
    ],
    "den": [
        FeatStruct(NUM="sg", GEN="mas", KAS="akk"),
        FeatStruct(NUM="pl", KAS="dat"),
    ],
    "die": [
        FeatStruct(NUM="sg", GEN="fem", KAS="nom"),
        FeatStruct(NUM="sg", GEN="fem", KAS="akk"),
        FeatStruct(NUM="pl", KAS="nom"),
        FeatStruct(NUM="pl", KAS="akk")
    ],
    "das": [
        FeatStruct(NUM="sg", GEN="neu", KAS="nom"),
        FeatStruct(NUM="sg", GEN="neu", KAS="akk"),
    ]
}

# %%
def predict(artikel, nomen):
    for art_fs in lexicon[artikel]:
        for nom_fs in lexicon[nomen]:
            if art_fs.unify(nom_fs):
                return True
    return False

# %%
test_cases = [
    (det, noun)
    for det in ["der", "des", "dem", "den", "die", "das"]
    for noun in ["Messer", "Löffel", "Gabel"]
]
truth = [
    True, True, True,
    False, False, False,
    True, True, False,
    False, True, False,
    True, True, True,
    True, False, False
]

predictions = []
for artikel, nomen in test_cases:
    predictions.append(predict(artikel, nomen))

print(
    "Accuracy: {:.0f}%".format(
        accuracy_score(truth, predictions)*100
    )
)
# Out:
# Accuracy: 100%

# %% [markdown]
# ---
# ## Aufgabe 8: Deklinationsmuster
#
# #### Nach welchem Deklinationsmuster wurde in den folgenden Beispielen das Adjektiv dekliniert?
#
# - *du blöder Kerl*
# - *du dumme Gans*
# - *du albernes Huhn*
#
# #### Beantworten Sie auch die folgenden Fragen.

# %%
aufgabe(blatt6_8)
# Out:
# Lueckentext(children=(HTML(value='<i>Vervollständigen Sie den Lückentext: </i>', layout=Layout(justify_content…

# %% [markdown]
# ---
# ## Aufgabe 9: Fragen zu NLTK-Kapitel 9.1
#
# #### Lesen Sie das NLTK-Teilkapitel 9.1 (’Grammatical Features’).
# #### Beantworten Sie insbesondere folgende Fragen:

# %% [markdown]
# ---
# ### Aufgabe 9 a:
#
# #### Worin besteht der Unterschied zwischen dem Einsatz von *Features* im POS-Tagging gegenüber dem Einsatz von *Features* in formalen Grammatiken?

# %%
aufgabe(blatt6_9a)
# Out:
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Wie werden Features beim POS-Tagging verwende…
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Wie werden Features in formalen Grammatiken v…

# %% [markdown]
# ---
# ### Aufgabe 9 b:

# %%
aufgabe(blatt6_9b)
# Out:
# SingleChoice(children=(HTML(value='<h4 style="font-size:14px;">Welche native python-Datenstruktur bietet sich …

# %% [markdown]
# ---
# ### Aufgabe 9 c:

# %%
aufgabe(blatt6_9c)
# Out:
# SelectionList(children=(HTML(value='<h4 style="font-size:14px;">Um welchen Faktor erhöht sich die Regelanzahl,…

# %% [markdown]
# ---
# ## Aufgabe 10: Fragen zu NLTK-Kapitel 9.2
#
# #### Lesen Sie das NLTK-Teilkapitel 9.2 (’Processing Feature Structures’): http://www.nltk.org/book/ch09.html.
#
# #### Beantworten Sie insbesondere folgende Fragen:

# %% [markdown]
# ---
# ### Aufgabe 10 a:
# #### Welchen Wert hat der feature path <code>(’spouse’, ’address’, ’number’)</code> in (22):(http://www.nltk.org/book/ch09.html#ex-dag03) ? Geben Sie einen zu diesem Pfad äquivalenten Pfad an.

# %%
aufgabe(blatt6_10a)
# Out:
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Beantworten Sie die beiden obigen Fragen.</h4…

# %% [markdown]
# ---
# ### Aufgabe 10 b:
#
# #### Geben Sie zwei linguistische Merkmalstrukturen FS<sub>0</sub> und FS<sub>1</sub> an, die in einer Subsumptionsbeziehung stehen (FS<sub>0</sub> ⊑ FS<sub>1</sub> ). Was kommt nach (26), Kapitel 9.2.1, dabei heraus, wenn man solche zwei Merkmalstrukturen unifiziert?

# %%
aufgabe(blatt6_10b)
# Out:
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Welche Beispiele erfüllen die obige Subsumpti…
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Was gilt immer für das Ergebnis der Unifikati…

# %% [markdown]
# ---
# ### Aufgabe 10 c:

# %%
aufgabe(blatt6_10c)
# Out:
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Welche der Beispiele erfüllen die Subsumption…

# %% [markdown]
# ---
# ### Aufgabe 10 d:

# %%
aufgabe(blatt6_10d)
# Out:
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Im Falle, dass im Zuge einer Unifikation Info…

# %% [markdown]
# ---
# ### Aufgabe 10 e:

# %%
aufgabe(blatt6_10e)
# Out:
# MultipleChoice(children=(HTML(value='<h4 style="font-size:14px;">Wie läßt sich im NLTK ein äquivalenter Pfad d…
